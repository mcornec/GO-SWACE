# %% [markdown]
# # Load and Plot SWOT EXPERT Data

# %%
import earthaccess
import xarray as xr
from xarray.backends.api import open_datatree
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
#%matplotlib widget

# %% [markdown]
# Log into earthaccess

# %%
auth = earthaccess.login(persist=True)

# %% [markdown]
# Check the names of the SWOT datasets available on earthaccess

# %%
results = earthaccess.search_datasets(keyword="swot")
for item in results:
    summary = item.summary()
    print(summary["short-name"])
# Out:
# SWOT_L2_HR_RiverSP_2.0
# SWOT_L2_LR_SSH_2.0
# SWOT_L2_HR_LakeSP_2.0
# SWOT_L2_HR_PIXC_2.0
# SWOT_L2_HR_Raster_2.0
# SWOT_L2_NALT_IGDR_2.0
# SWOT_L2_LR_SSH_1.0
# SWOT_L2_NALT_GDR_2.0
# SWOT_L2_HR_LakeSP_1.1
# SWOT_L2_HR_RiverSP_1.1
# SWOT_L2_NALT_OGDR_2.0
# SWOT_L1B_HR_SLC_1.1
# SWOT_L2_LR_SSH_1.1
# SWOT_L1B_HR_SLC_2.0
# SWOT_L2_HR_PIXCVec_2.0
# SWOT_L2_HR_PIXC_1.1
# SWOT_L2_NALT_IGDR_1.0
# SWOT_L2_NALT_OGDR_1.0
# SWOT_L2_RAD_IGDR_2.0
# SWOT_L1B_LR_INTF_1.0
# SWOT_L4_DAWG_SOS_DISCHARGE
# SWOT_L2_HR_LakeSP_obs_2.0
# SWOT_L2_HR_LakeSP_prior_2.0
# SWOT_L2_HR_LakeSP_unassigned_2.0
# SWOT_L2_HR_PIXCVec_1.1
# SWOT_L2_HR_Raster_1.1
# SWOT_L2_HR_Raster_100m_2.0
# SWOT_L2_HR_Raster_250m_2.0
# SWOT_L2_HR_RiverAvg_2.0
# SWOT_L2_HR_RiverSP_node_2.0
# SWOT_L2_HR_RiverSP_reach_2.0
# SWOT_L2_LR_SSH_BASIC_2.0
# SWOT_L2_LR_SSH_EXPERT_2.0
# SWOT_L2_LR_SSH_UNSMOOTHED_2.0
# SWOT_L2_LR_SSH_WINDWAVE_2.0
# SWOT_L2_NALT_GDR_GDR_2.0
# SWOT_L2_NALT_GDR_SGDR_2.0
# SWOT_L2_NALT_GDR_SSHA_2.0
# SWOT_L2_NALT_IGDR_GDR_1.0
# SWOT_L2_NALT_IGDR_GDR_2.0
# SWOT_L2_NALT_IGDR_SGDR_1.0
# SWOT_L2_NALT_IGDR_SGDR_2.0
# SWOT_L2_NALT_IGDR_SSHA_1.0
# SWOT_L2_NALT_IGDR_SSHA_2.0
# SWOT_L2_NALT_OGDR_GDR_1.0
# SWOT_L2_NALT_OGDR_GDR_2.0
# SWOT_L2_NALT_OGDR_SSHA_1.0
# SWOT_L2_NALT_OGDR_SSHA_2.0
# SWOT_L2_RAD_GDR_2.0
# SWOT_L2_RAD_IGDR_1.0
# SWOT_L2_RAD_OGDR_1.0
# SWOT_L2_RAD_OGDR_2.0
# SWOT_L1B_LR_INTF_2.0
# SWOT_L1_DORIS_RINEX_1.0
# SWOT_L1_GPSP_RINEX_1.0
# SWOT_ATTD_RECONST_2.0
# SWOT_MOE_1.0
# SWOT_POE_2.0
# SWOT_SAT_COM_1.0
# SWOT_L1B_LR_INTF_1.1
# DeltaX_L2_AirSWOT_WaterElev_V2_2128
# ABoVE_AirSWOT_Radar_Data_1646
# SWOT_SIMULATED_NA_CONTINENT_L2_HR_LAKESP_V1
# SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXCVEC_V1
# SWOT_SIMULATED_NA_CONTINENT_L2_HR_PIXC_V1
# SWOT_SIMULATED_NA_CONTINENT_L2_HR_RASTER_V1
# SWOT_SIMULATED_NA_CONTINENT_L2_HR_RIVERSP_V1
# SWOT_PRELAUNCH_L2_BPR_V1
# SWOT_PRELAUNCH_L2_GPS_V1
# SWOT_PRELAUNCH_L2_WHOICTD_V1
# SWOT_PRELAUNCH_L2_PIES_V1
# SWOT_PRELAUNCH_L2_SIOCTD_V1
# SWOT_PRELAUNCH_L2_PRAWLER_V1
# SWOT_PRELAUNCH_L2_GLIDER_V1
# PRESWOT_HYDRO_L4_LAKE_STORAGE_TIME_SERIES_V2
# PRESWOT_HYDRO_L2_GREALM_LAKE_HEIGHT_V2
# SWOT_PRELAUNCH_L2_WW_V1
# PRESWOT_HYDRO_GRRATS_L2_VIRTUAL_STATION_HEIGHTS_V2
# PRESWOT_HYDRO_GRRATS_L2_DAILY_VIRTUAL_STATION_HEIGHTS_V2
# PRESWOT_HYDRO_L3_LAKE_RESEVOIR_AREA_V2
# SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_CALVAL_V1
# SWOT_SIMULATED_L2_NADIR_SSH_GLORYS_CALVAL_V1
# SWOT_SIMULATED_L2_KARIN_SSH_GLORYS_SCIENCE_V1
# SWOT_SIMULATED_L2_NADIR_SSH_GLORYS_SCIENCE_V1
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_ACC_SMST_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_BassStrait_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_Boknis_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_CapeBasin_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_GotlandBasin_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_LabradorSea_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_MarmaraSea_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_NWAustralia_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_NWPacific_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_NewCaledonia_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_ROAM_MIZ_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_RockallTrough_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_WestAtlantic_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_WesternMed_v1.0
# MITgcm_LLC4320_Pre-SWOT_JPL_L4_Yongala_v1.0
# SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_SCIENCE_V1
# SWOT_SIMULATED_L2_NADIR_SSH_ECCO_LLC4320_SCIENCE_V1
# SWOT_SIMULATED_L2_KARIN_SSH_ECCO_LLC4320_CALVAL_V1
# SWOT_SIMULATED_L2_NADIR_SSH_ECCO_LLC4320_CALVAL_V1
# MUR-JPL-L4-GLOB-v4.1
# BAROCLINIC_HRET14

# %%
def get_swot_data(latmin,latmax,lonmin,lonmax,tmin,tmax):
    """
    Searches for SWOT data within the bounding box and time. Note that this doesn't work for unsmoothed data. 
    
    latmin,latmax: latitude bounds, degrees N (south is negative); floats
    lonmin, lonmax: longitude bounds, degrees E (west is negative); floats
    tmin,tmax: temporal bounds; strings of form 'yyyy-mm-dd'
    """
    bbox = (lonmin, latmin, lonmax, latmax) # lonW, latS, lonE, latN
    results = earthaccess.search_data(
        short_name="SWOT_L2_LR_SSH_EXPERT_2.0",
        bounding_box=bbox,
        temporal=(tmin,tmax))
    
    print("Number of swaths: " + str(len(results))) # not daily files, so will likely be more than # of days
    paths = earthaccess.open(results) # is there a way to choose a subset of variables here?

    return paths

# %% [markdown]
# ### Looking for Gulf Stream Ring <3 Edward <3

# %%
latmin,latmax = 34,38
lonmin,lonmax = -73,-68
tmin,tmax = '2024-04-03','2024-08-05' #'2024-04-17','2024-08-04'

edward_paths = get_swot_data(latmin,latmax,lonmin,lonmax,tmin,tmax)
# Out:
# Number of swaths: 88
# QUEUEING TASKS | :   0%|          | 0/88 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/88 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/88 [00:00<?, ?it/s]

# %% [markdown]
# Get all dates with SWOT swaths through the bounding box

# %%
dates_available = []
for i in edward_paths:
    today = str(i).split('-')[-1].split('_')[-4][0:8]
    if today not in dates_available:
        dates_available.append(today)
print(dates_available)
# Out:
# ['20240405', '20240406', '20240407', '20240408', '20240416', '20240417', '20240418', '20240420', '20240426', '20240427', '20240428', '20240429', '20240507', '20240508', '20240509', '20240517', '20240518', '20240519', '20240523', '20240527', '20240528', '20240529', '20240530', '20240531', '20240607', '20240608', '20240609', '20240613', '20240617', '20240618', '20240619', '20240620', '20240621', '20240628', '20240629', '20240630', '20240704', '20240708', '20240709', '20240710', '20240711', '20240712', '20240719', '20240720', '20240721', '20240725', '20240729', '20240730', '20240801']

# %% [markdown]
# Get data from a specific date
#
# NOTE: 2024/05/23 isn't cropping

# %%
date_requested = '20240508'

ind = 0 
for i in edward_paths:
    today = str(i).split('-')[-1].split('_')[-4][0:8]
    if date_requested == today:
        print(ind)
    ind += 1
# Out:
# 23
# 24

# %%
print(edward_paths[23])
print(edward_paths[24])
# Out:
# <File-like object S3FileSystem, podaac-swot-ops-cumulus-protected/SWOT_L2_LR_SSH_2.0/SWOT_L2_LR_SSH_Expert_014_576_20240508T002317_20240508T011320_PIC0_01.nc>
# <File-like object S3FileSystem, podaac-swot-ops-cumulus-protected/SWOT_L2_LR_SSH_2.0/SWOT_L2_LR_SSH_Expert_015_007_20240508T131334_20240508T140502_PIC0_01.nc>

# %% [markdown]
# Open a single dataset

# %%
ds1 = xr.open_dataset(edward_paths[23])
ds2 = xr.open_dataset(edward_paths[24])

# %%
def crop_dataset_by_lat_lon(ds,latmin,latmax,lonmin,lonmax):
    mask = (ds.latitude >= latmin) & (ds.latitude <= latmax) & (ds.longitude >= lonmin+360) & (ds.longitude <= lonmax+360)
    ds_masked = ds.where(mask, drop=True)
    return ds_masked

# %%
ds1_masked = crop_dataset_by_lat_lon(ds1,latmin,latmax,lonmin,lonmax)
ds2_masked = crop_dataset_by_lat_lon(ds2,latmin,latmax,lonmin,lonmax)

# %% [markdown]
# Need to add 'height_cor_xover' values to ssh & sla variabiles

# %%
plt.clf()

fig,ax=plt.subplots(figsize=(8,5))
plot = ax.pcolormesh(ds_masked.longitude,ds_masked.latitude,ds_masked.height_cor_xover)
cbar = plt.colorbar(plot,ax=ax)

cbar.set_label('Height Correction (m)', rotation=270, labelpad=15)

ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')

plt.show()

# %% [markdown]
# SSHA Karin 2 is the best quality to show the eddy

# %%
plt.clf()

fig,ax=plt.subplots(figsize=(8,5))
plot = ax.pcolormesh(ds_masked.longitude,ds_masked.latitude,np.add(ds_masked.ssha_karin_2,ds_masked.height_cor_xover),cmap='coolwarm')#,vmin=-48,vmax=-43)
cbar = plt.colorbar(plot,ax=ax)

cbar.set_label('SLA (m)', rotation=270, labelpad=15)

ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
ax.set_title(date_requested)

plt.show()

# %% [markdown]
# Plot overlap

# %%
plt.clf()

fig,ax=plt.subplots(figsize=(8,5))
plot = ax.pcolormesh(ds1_masked.longitude,ds1_masked.latitude,np.add(ds1_masked.ssha_karin_2,ds1_masked.height_cor_xover),cmap='coolwarm')#,vmin=-48,vmax=-43)
ax.pcolormesh(ds2_masked.longitude,ds2_masked.latitude,np.add(ds2_masked.ssha_karin_2,ds2_masked.height_cor_xover),cmap='coolwarm')#,vmin=-48,vmax=-43)

cbar = plt.colorbar(plot,ax=ax)

cbar.set_label('SLA (m)', rotation=270, labelpad=15)

ax.set_ylabel('Latitude')
ax.set_xlabel('Longitude')
ax.set_title(date_requested)

plt.show()
